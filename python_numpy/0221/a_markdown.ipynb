# %% [markdown]
# Markdown
# =====
# 텍스트에 서식을 지정할 수 있는 경량 텍스트 언어
# HTML과 같은 다른 마크업 언어에 비해 사용이 편함

# %%
#? 제목 표시
#? h1 ~ h6 제목의 크기와 중요도
#? h1 : 가장 중요한 제목
#? h6 : 단락의 제목

#? # : h1 제목
#? ## : h2 제목
#? ### : h3 제목
#? #### : h4 제목
#? ##### : h5 제목
#? ###### : h6 제목

#? 내용
#? =====
#? 🔼h1

#? 내용
#? -----
#? 🔼h2

# %% [markdown]
# # h1
# ## h2
# ### h3
# #### h4
# ##### h5
# ###### h6

# %% [markdown]
# h1
# ===
# h2
# ---

# %%
#? 문자 강조
#? 이텔릭체, 볼드체, 취소선, 밑줄

#? *내용* | _내용_ : 이텔릭체
#? **내용** | __내용__ : 볼드체
#? ~~내용~~ : 취소선

#? 밑줄은 마크다운에서 지원하지 않음
#? HTML 밑줄 사용법
#? <u>내용</u> : 밑줄

# %% [markdown]
# *이텔릭체*
# **볼드체**
# _**두꺼운**이텔릭체_
# ~~취소선~~
# <u>밑줄</u>

# %%
#? 줄바꿈
#? 띄워쓰기 두번으로 줄바꿈 처리
#? <br>으로 줄바꿈 처리

# %% [markdown]
# 첫번째줄
# 두번째줄
# 세번째줄

# %% [markdown]
# 첫번째줄<br>두번째줄<br>세번째줄

# %%
#? 글자 색상
#? 마크다운은 글자 색상에 대한 스타일을 지원하지 않음
#? 다른 마크업 언어의 스타일 사용
#? HTML의 <span style='color:색상;'>내용</span> : 글자 색상
#? HTML의 <span style='background-color:색상;'>내용</span> : 글자 배경색상

#? 키워드로 된 색상과 rgb 혹은 hex 값으로 지정 가능

# %% [markdown]
# <span style='color: red;'>빨간 글씨</span>
# <span style='background-color: rgba(255,255,0,0.4);'>형광느낌</span>

# %%
#? 코드 표시
#? 인라인 표시방식, 블럭 표시방식
#? 인라인 표시방식 - 지정한 글자에 대해서만 표시
#? 블럭 표시방식 - 지정한 문단 전체에 대해서 표시

#? `내용`으로 감싸서 인라인 표시 가능
#? ```내용```으로 감싸서 블럭 표시 가능

#? ```언어
#? 내용
#? ```    으로 특정 언어로 코드 강조 표시

# %% [markdown]
# `private static` 표시
# ```python
# for index in range(10):
#   print(index)
# ```

# %%
#? 실선, 구분선
#? ***, ___ : 가로 실선 표시
#? <hr>: 가로 실선

# %% [markdown]
# ***
# 안녕
# ___
# 잘가
# <hr>

# %%
#? 테이블 표시
#? |컬럼명1|컬럼명2|컬럼명3|
#? | --- | --- | --- |
#? | 필드1 | 필드2 | 필드3 |
#? | 필드4 | 필드5 | 필드6 |
#? 🔼테이블 표시가능

#? '---', ':---' : 좌측정렬
#? '---:' : 우측정렬
#? ':---:' : 중앙정렬

# %% [markdown]
# |컬럼명1|컬럼명2|컬럼명3|
# | :---: | :---: | :---: |
# | 필드1 | 필드2 | 필드3 |
# | 필드4 | 필드5 | 필드6 |

# %%
#? 이미지
#? ![대체텍스트](이미지 주소)
#? ![대체텍스트](이미지 주소 '이미지 설명')

# %% [markdown]
# ![강아지](https://cdn.pixabay.com/photo/2016/02/18/18/37/puppy-1207816_1280.jpg)
#
# ![강아지](https://cdn.pixabay.com/photo/2016/02/18/18/37/puppy-1207816_1280.jpg "귀여운 강아지")

# %%
#? 링크
#? [이름](링크)
#? [이름](링크 "링크 설명")

# %% [markdown]
# [구글](https://google.com)
# [네이버](https://naver.com "네이버 홈페이지")
