# %% [markdown]
# Markdown
# =====
# 텍스트에 서식을 지정할 수 있는 경량 텍스트 언어
# HTML과 같은 다른 마크업 언어에 비해 사용이 편함

# %%
#? 제목 표시
#? h1 ~ h6 제목의 크기와 중요도
#? h1 : 가장 중요한 제목
#? h6 : 단락의 제목

#? # : h1 제목
#? ## : h2 제목
#? ### : h3 제목
#? #### : h4 제목
#? ##### : h5 제목
#? ###### : h6 제목

#? 내용
#? =====
#? 🔼h1

#? 내용
#? -----
#? 🔼h2

# %% [markdown]
# # h1
# ## h2
# ### h3
# #### h4
# ##### h5
# ###### h6

# %% [markdown]
# h1
# ===
# h2
# ---

# %%
#? 문자 강조
#? 이텔릭체, 볼드체, 취소선, 밑줄

#? *내용* | _내용_ : 이텔릭체
#? **내용** | __내용__ : 볼드체
#? ~~내용~~ : 취소선

#? 밑줄은 마크다운에서 지원하지 않음
#? HTML 밑줄 사용법
#? <u>내용</u> : 밑줄

# %% [markdown]
# *이텔릭체*
# **볼드체**
# _**두꺼운**이텔릭체_
# ~~취소선~~
# <u>밑줄</u>

# %%
#? 줄바꿈
#? 띄워쓰기 두번으로 줄바꿈 처리
#? <br>으로 줄바꿈 처리

# %% [markdown]
# 첫번째줄
# 두번째줄
# 세번째줄

# %% [markdown]
# 첫번째줄<br>두번째줄<br>세번째줄
